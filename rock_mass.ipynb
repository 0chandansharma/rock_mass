# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#use=['rmr','min','max','mean']

# %%
df=pd.read_csv(r"C:\Users\chandan sharma\Desktop\lyric\GRAPHH.csv")

# %%
df.head()
# Out:
#    RMR  Em(field)    Em1  EM2(N&B)  EM3 (GOK)  EM4(Mitri)  EM5(chun)  \
# 0   44       0.92   7.07      2.57       2.03        9.02       2.72
# 1   49      12.70   9.44      3.20       2.97       10.76       3.47
# 2   45       3.41   7.49      2.81       2.19        9.37       2.86
# 3   55       0.87  10.00      3.05       4.68        9.55       4.64
# 4   60      11.20  14.00      3.72       6.82       10.81       5.92
#
#    EM6(Rama)
# 0       0.88
# 1       1.18
# 2       0.94
# 3       1.24
# 4       1.65

# %%
df.describe()
# Out:
#              RMR  Em(field)        Em1   EM2(N&B)  EM3 (GOK)  EM4(Mitri)  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000   24.000000
# mean   51.875000   5.637083  11.084167   3.702083   4.379167   11.647917
# std     8.414855   5.732623   7.951167   2.321328   2.468714    7.268489
# min    32.000000   0.800000   2.000000   0.410000   0.820000    1.480000
# 25%    47.250000   1.260000   5.905000   2.675000   2.610000    8.535000
# 50%    53.000000   3.235000   8.455000   3.370000   4.020000   10.785000
# 75%    57.000000   8.500000  14.000000   4.067500   5.440000   12.927500
# max    66.000000  21.400000  32.000000   9.900000  10.730000   30.110000
#
#        EM5(chun)  EM6(Rama)
# count  24.000000  24.000000
# mean    4.295833   1.450333
# std     1.599440   0.965469
# min     1.530000   0.120000
# 25%     3.197500   1.002000
# 50%     4.210000   1.295000
# 75%     5.120000   1.620000
# max     7.920000   4.170000

# %%
plt.scatter(df['RMR'], df['Em(field)'], color='green')
plt.title('RMR Vs Em_mean', fontsize=14)
plt.xlabel('Em(field)', fontsize=14)
plt.ylabel('RMR', fontsize=14)
plt.grid(True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
# RMR           24 non-null int64
# Em(field)     24 non-null float64
# Em1           24 non-null float64
# EM2(N&B)      24 non-null float64
# EM3 (GOK)     24 non-null float64
# EM4(Mitri)    24 non-null float64
# EM5(chun)     24 non-null float64
# EM6(Rama)     24 non-null float64
# dtypes: float64(7), int64(1)
# memory usage: 1.6 KB

# %%
df.describe()
# Out:
#              RMR  Em(field)        Em1   EM2(N&B)  EM3 (GOK)  EM4(Mitri)  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000   24.000000
# mean   51.875000   5.637083  11.084167   3.702083   4.379167   11.647917
# std     8.414855   5.732623   7.951167   2.321328   2.468714    7.268489
# min    32.000000   0.800000   2.000000   0.410000   0.820000    1.480000
# 25%    47.250000   1.260000   5.905000   2.675000   2.610000    8.535000
# 50%    53.000000   3.235000   8.455000   3.370000   4.020000   10.785000
# 75%    57.000000   8.500000  14.000000   4.067500   5.440000   12.927500
# max    66.000000  21.400000  32.000000   9.900000  10.730000   30.110000
#
#        EM5(chun)  EM6(Rama)
# count  24.000000  24.000000
# mean    4.295833   1.450333
# std     1.599440   0.965469
# min     1.530000   0.120000
# 25%     3.197500   1.002000
# 50%     4.210000   1.295000
# 75%     5.120000   1.620000
# max     7.920000   4.170000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(df.Em1,df.RMR color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], color='darkgreen', marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()
# Out:
#   File "<ipython-input-49-b60edaa0857e>", line 3
#     ax.plot(df.Em1,df.RMR color='lightblue', linewidth=3)
#                               ^
# SyntaxError: invalid syntax

# %%
#we need to normalize the features using mean normalization
df = (df - df.mean())/df.std()
df.head()
# Out:
#         RMR  Em(field)       Em1  EM2(N&B)  EM3 (GOK)  EM4(Mitri)  EM5(chun)  \
# 0 -0.935845  -0.822849 -0.504853 -0.487688  -0.951575   -0.361549  -0.985241
# 1 -0.341658   1.232057 -0.206783 -0.216291  -0.570810   -0.122160  -0.516327
# 2 -0.817008  -0.388493 -0.452030 -0.384299  -0.886764   -0.313396  -0.897710
# 3  0.371367  -0.831571 -0.136353 -0.280910   0.121858   -0.288632   0.215179
# 4  0.965554   0.970396  0.366718  0.007718   0.988707   -0.115281   1.015460
#
#    EM6(Rama)
# 0  -0.590732
# 1  -0.280002
# 2  -0.528586
# 3  -0.217856
# 4   0.206808

# %%
    X = df[['RMR','Em1' , 'EM2(N&B)', 'EM3 (GOK)', 'EM4(Mitri)', 'EM5(chun)', 'EM6(Rama)']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
    Y = df['Em(field)']

# %%
X
# Out:
#          RMR       Em1  EM2(N&B)  EM3 (GOK)  EM4(Mitri)  EM5(chun)  EM6(Rama)
# 0  -0.935845 -0.504853 -0.487688  -0.951575   -0.361549  -0.985241  -0.590732
# 1  -0.341658 -0.206783 -0.216291  -0.570810   -0.122160  -0.516327  -0.280002
# 2  -0.817008 -0.452030 -0.384299  -0.886764   -0.313396  -0.897710  -0.528586
# 3   0.371367 -0.136353 -0.280910   0.121858   -0.288632   0.215179  -0.217856
# 4   0.965554  0.366718  0.007718   0.988707   -0.115281   1.015460   0.206808
# 5   0.609042  1.121324 -0.168905   0.429711   -0.218466   0.515285  -0.062491
# 6   0.133692 -0.639424 -0.117210  -0.145487   -0.087765  -0.053665  -0.103922
# 7   0.846717  0.869788  0.283422   0.790223    0.168134   0.840398   0.465750
# 8   0.490205  0.115182  0.072336   0.267683    0.041561   0.365232   0.165377
# 9  -0.460495 -0.273440 -0.082747  -0.659925    0.033306  -0.616362  -0.456082
# 10  0.133692 -0.639424  0.270499  -0.145487    0.296084  -0.053665  -0.103922
# ...

# %%
Y
# Out:
# 0    -0.822849
# 1     1.232057
# 2    -0.388493
# 3    -0.831571
# 4     0.970396
# 5    -0.439081
# 6    -0.784472
# 7     1.319277
# 8    -0.308250
# 9    -0.756562
# 10    1.465807
# 11   -0.238474
# 12   -0.843782
# 13    1.476273
# 14   -0.398959
# 15   -0.843782
# 16    0.272636
# 17   -0.564677
# 18   -0.512345
# 19    2.749686
# 20    0.342412
# 21   -0.826338
# 22   -0.547233
# 23   -0.721674
# Name: Em(field), dtype: float64

# %%
plt.scatter(df['RMR'], df['Em(field)'], color='green')
plt.title('RMR Vs Em_mean', fontsize=14)
plt.xlabel('Em_mean', fontsize=14)
plt.ylabel('RMR', fontsize=14)
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from time import time

# Prepare the data
X_train = df.drop("Em(field)",axis=1)
y_train = df["Em(field)"]

# %%
X_train
# Out:
#          RMR       Em1  EM2(N&B)  EM3 (GOK)  EM4(Mitri)  EM5(chun)  EM6(Rama)
# 0  -0.935845 -0.504853 -0.487688  -0.951575   -0.361549  -0.985241  -0.590732
# 1  -0.341658 -0.206783 -0.216291  -0.570810   -0.122160  -0.516327  -0.280002
# 2  -0.817008 -0.452030 -0.384299  -0.886764   -0.313396  -0.897710  -0.528586
# 3   0.371367 -0.136353 -0.280910   0.121858   -0.288632   0.215179  -0.217856
# 4   0.965554  0.366718  0.007718   0.988707   -0.115281   1.015460   0.206808
# 5   0.609042  1.121324 -0.168905   0.429711   -0.218466   0.515285  -0.062491
# 6   0.133692 -0.639424 -0.117210  -0.145487   -0.087765  -0.053665  -0.103922
# 7   0.846717  0.869788  0.283422   0.790223    0.168134   0.840398   0.465750
# 8   0.490205  0.115182  0.072336   0.267683    0.041561   0.365232   0.165377
# 9  -0.460495 -0.273440 -0.082747  -0.659925    0.033306  -0.616362  -0.456082
# 10  0.133692 -0.639424  0.270499  -0.145487    0.296084  -0.053665  -0.103922
# ...

# %%
y_train
# Out:
# 0    -0.822849
# 1     1.232057
# 2    -0.388493
# 3    -0.831571
# 4     0.970396
# 5    -0.439081
# 6    -0.784472
# 7     1.319277
# 8    -0.308250
# 9    -0.756562
# 10    1.465807
# 11   -0.238474
# 12   -0.843782
# 13    1.476273
# 14   -0.398959
# 15   -0.843782
# 16    0.272636
# 17   -0.564677
# 18   -0.512345
# 19    2.749686
# 20    0.342412
# 21   -0.826338
# 22   -0.547233
# 23   -0.721674
# Name: Em(field), dtype: float64

# %%
test = pd.read_csv(r"C:\Users\chandan sharma\Desktop\lyric\test_real.csv")

# %%
# Separate the features and the target variable
X_test = test.drop("mean", axis=1)
y_test = test["mean"]

# %%
X_test
# Out:
#    rmr    max   min
# 0   45  12.70  0.92
# 1   57  11.20  0.87
# 2   56  13.20  1.14
# 3   51  14.04  1.30
# 4   51  14.10  0.80
# 5   64   7.20  0.80
# 6   54  21.40  2.70
# 7   36   2.50  0.90

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
y_test
# Out:
# 0     3.41
# 1     3.12
# 2     3.87
# 3     4.27
# 4     3.35
# 5     2.40
# 6    10.31
# 7     0.51
# Name: mean, dtype: float64

# %%
# Train the model using the training sets
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Make predictions using the testing set
y_pred = regr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-97a1457478b1> in <module>
#       1 # Make predictions using the testing set
# ----> 2 y_pred = regr.predict(X_test)
#
# ~\project\Anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     266             Returns predicted values.
#     267         """
# --> 268         return self._decision_function(X)
#     269
#     270     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\project\Anaconda3\envs\myenv\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     251         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     252         return safe_sparse_dot(X, self.coef_.T,
# --> 253                                dense_output=True) + self.intercept_
#     254
#     255     def predict(self, X):
#
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [  4.94252285   0.11028074  19.52262045   6.58807    -16.94826079
#  -12.34311219  -2.04067264]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-9eb0e3a9f881> in <module>
#       3 # The mean squared error
#       4 print("Mean squared error: %.2f"
# ----> 5       % mean_squared_error(y_test, y_pred))
#       6 # Explained variance score: 1 is perfect prediction
#       7 print('Variance score: %.2f' % r2_score(y_test, y_pred))
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn import metrics

from sklearn import preprocessing

# %%
#print("percentage error:",(np.mean(np.abs(y_test - y_pred) / y_test)*100))

# %%
from math import sqrt

# %%
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))

print('R2 score: %.2f' % r2_score(y_test, y_pred))

#print("Mean absolute error:%.2f" % mean_absolute_error(y_test, y_pred))

meanSquaredError=mean_squared_error(y_test, y_pred)
print("MSE:", meanSquaredError)
rootMeanSquaredError = sqrt(meanSquaredError)
print("RMSE:", rootMeanSquaredError)
# Out:
# Mean squared error: 8.53
# R2 score: -0.22
# MSE: 8.526022872414972
# RMSE: 2.9199354226446466
